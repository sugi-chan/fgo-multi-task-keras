# %%
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.applications.vgg19 import VGG19
from keras.preprocessing import image
from keras.applications.vgg19 import preprocess_input
import cv2
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %pylab inline
# Out:
# d:\users\micha\appdata\local\programs\python\python35\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import cv2
model = load_model('models/best_run5_smaller.h5')

img = image.load_img('test/saber1.jpg',target_size=(224, 224)) #read in image
img = image.img_to_array(img)
img = preprocess_input(img)
# Load an color image in grayscale
#img = cv2.imread('images/0defe15146155708d28195cff615d18b--ears-anime-art.jpg')
#cv2.imshow('zz',img)
#k = cv2.waitKey(0)
#cv2.destroyAllWindows()
#img = cv2.resize(img,(299,299))

# %%
prediction = model.predict(np.array([img]))

# %%
def extract_label(label_list, pred_array):
    pred_max = pred_array.argmax()
    
    return label_list[pred_max]

def extract_top_3(label_list, pred_array):
    max_ = pred_array.argsort()[0][-1]
    second_ = pred_array.argsort()[0][-2]
    third_ = pred_array.argsort()[0][-3]
    
    return [label_list[max_],label_list[second_],label_list[third_]]
    
gender = ['Female',
       'Male']
region = ['Asia', 'Egypt', 'Europe',
       'Middle East']
fighting_style = ['magic', 'melee',
       'ranged']
alignment = ['CE', 'CG', 'CN',
       'LE', 'LG', 'LN', 'NE',
       'NG', 'TN']
colors = ['white', 'red',
       'green', 'black', 'blue', 'purple', 'gold', 'silver']


print(extract_label(gender, prediction[0]))
print(extract_label(region, prediction[1]))
print(extract_label(fighting_style, prediction[2]))
print(extract_label(alignment, prediction[3]))
print(extract_top_3(colors, prediction[4]))
#print(prediction[0].argmax(),prediction[0])
# Out:
# Female
# Europe
# melee
# LG
# ['silver', 'gold', 'blue']

# %%
from os import listdir

test = listdir('test/')
    
for i in test:
    img = image.load_img('test/'+i,target_size=(224, 224)) #read in image
    img = image.img_to_array(img)
    img = preprocess_input(img)
    prediction = model.predict(np.array([img]))
    print(i)
    
    
    print('')
    print('image: ', i )
    print(extract_label(gender, prediction[0]))
    print(extract_label(region, prediction[1]))
    print(extract_label(fighting_style, prediction[2]))
    print(extract_label(alignment, prediction[3]))
    print(extract_top_3(colors, prediction[4]))
    
    im2 = image.load_img('test/'+i)
    plt.imshow(im2)
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.show()
# Out:
# 331453-Fate_Series-Saber_Lily-748x1008.png
#
# image:  331453-Fate_Series-Saber_Lily-748x1008.png
# Female
# Asia
# melee
# TN
# ['white', 'blue', 'green']
# arthur1.jpg
#
# image:  arthur1.jpg
# Female
# Europe
# melee
# LG
# ['silver', 'gold', 'white']
# arthur2.jpg
#
# image:  arthur2.jpg
# Female
# Europe
# melee
# LG
# ['purple', 'silver', 'white']
# arturia1.png
#
# image:  arturia1.png
# Female
# Asia
# melee
# CE
# ['black', 'purple', 'gold']
# gilgamesh.png
#
# image:  gilgamesh.png
# Male
# Asia
# magic
# LG
# ['gold', 'blue', 'white']
# gilgamesh2.jpg
#
# image:  gilgamesh2.jpg
# Male
# Asia
# magic
# LG
# ['gold', 'white', 'blue']
# gilgamesh3.jpg
#
# image:  gilgamesh3.jpg
# Male
# Europe
# melee
# CG
# ['red', 'gold', 'black']
# gilgamesh4.jpg
#
# image:  gilgamesh4.jpg
# Male
# Middle East
# ranged
# LG
# ['gold', 'blue', 'white']
# ishtar1.jpg
#
# image:  ishtar1.jpg
# Female
# Europe
# melee
# LG
# ['gold', 'purple', 'white']
# ishtar2.jpg
#
# image:  ishtar2.jpg
# Male
# Europe
# ranged
# LG
# ['gold', 'black', 'green']
# ishtar3.png
#
# image:  ishtar3.png
# Male
# Asia
# melee
# LG
# ['black', 'red', 'purple']
# ishtar4.jpg
#
# image:  ishtar4.jpg
# Male
# Asia
# melee
# LG
# ['gold', 'blue', 'white']
# jalter1.jpg
#
# image:  jalter1.jpg
# Male
# Europe
# melee
# LG
# ['black', 'red', 'gold']
# jalter2.jpg
#
# image:  jalter2.jpg
# Female
# Europe
# melee
# CE
# ['red', 'gold', 'purple']
# jalter3.jpg
#
# image:  jalter3.jpg
# Female
# Europe
# melee
# CE
# ['black', 'purple', 'red']
# larturia.png
#
# image:  larturia.png
# Female
# Europe
# melee
# LG
# ['white', 'blue', 'silver']
# merlin.png
#
# image:  merlin.png
# Female
# Asia
# magic
# NE
# ['blue', 'white', 'purple']
# morderd1.png
#
# image:  morderd1.png
# Female
# Asia
# melee
# NE
# ['purple', 'black', 'gold']
# musashi.jpg
#
# image:  musashi.jpg
# Female
# Europe
# melee
# CN
# ['red', 'black', 'silver']
# musashi2.jpg
#
# image:  musashi2.jpg
# Female
# Asia
# ranged
# LG
# ['gold', 'white', 'red']
# okita.jpg
#
# image:  okita.jpg
# Female
# Asia
# melee
# TN
# ['white', 'blue', 'green']
# okita2.jpg
#
# image:  okita2.jpg
# Female
# Asia
# melee
# TN
# ['white', 'blue', 'green']
# ozy.jpg
#
# image:  ozy.jpg
# Male
# Egypt
# magic
# CN
# ['gold', 'white', 'blue']
# saber1.jpg
#
# image:  saber1.jpg
# Female
# Europe
# melee
# LG
# ['silver', 'gold', 'blue']
# saber2.jpg
#
# image:  saber2.jpg
# Male
# Asia
# ranged
# LG
# ['white', 'blue', 'gold']
# saber3.jpg
#
# image:  saber3.jpg
# Male
# Europe
# magic
# LG
# ['blue', 'gold', 'silver']
# saber4.png
#
# image:  saber4.png
# Female
# Europe
# melee
# LE
# ['black', 'blue', 'purple']
# santaalter.jpg
#
# image:  santaalter.jpg
# Female
# Europe
# melee
# LG
# ['purple', 'silver', 'gold']
# scattach.png
#
# image:  scattach.png
# Female
# Europe
# melee
# NG
# ['purple', 'black', 'red']
# stheno.jpg
#
# image:  stheno.jpg
# Male
# Europe
# ranged
# LN
# ['green', 'white', 'gold']
# wlop.jpg
#
# image:  wlop.jpg
# Male
# Europe
# melee
# LG
# ['gold', 'silver', 'blue']
